# %%
import pandas as pd
import math
import folium
import json

# %%
def col_change(df):
    df.columns = ['연도','시도','시군구','계약종별',
                  '1월','2월','3월','4월','5월',
                  '6월','7월','8월','9월','10월',
                  '11월','12월']

    df.drop([0, 1], axis=0, inplace=True)

    return df

# %%
df2010 = pd.read_excel("시군구별 전력사용량(2010년).xlsx")
df2011 = pd.read_excel("시군구별 전력사용량(2011년).xlsx")
df2012 = pd.read_excel("시군구별 전력사용량(2012년).xlsx")
df2013 = pd.read_excel("시군구별 전력사용량(2013년).xlsx")
df2014 = pd.read_excel("150128 시군구별 전력사용량(2014년 1월~12월).xlsx")
df2015 = pd.read_excel("시군구별 전력사용량(2015년 12월).xlsx")
df2016 = pd.read_excel("시군구별 전력사용량(2016년 12월).xlsx")
df2017 = pd.read_excel("8.시군구별 전력사용량(홈페이지 게시용)_201712.xlsx")
df2018 = pd.read_excel("8.시군구별 전력사용량(홈페이지 게시용)_201812.xlsx")
df2019 = pd.read_excel("(2019)시군구별 전력사용량.xlsx")
df2020 = pd.read_excel("시군구별 전력사용량(홈페이지 게시용)_202012.xlsx")
df2021 = pd.read_excel("8.시군구별 전력사용량(홈페이지 게시용)_202112.xlsx")

df2010 = col_change(df2010).reset_index()
df2011 = col_change(df2011).reset_index()
df2012 = col_change(df2012).reset_index()
df2013 = col_change(df2013).reset_index()
df2014 = col_change(df2014).reset_index()
df2015 = col_change(df2015).reset_index()
df2016 = col_change(df2016).reset_index()
df2017 = col_change(df2017).reset_index()
df2018 = col_change(df2018).reset_index()
df2019 = col_change(df2019).reset_index()
df2020 = col_change(df2020).reset_index()
df2021 = col_change(df2021).reset_index()

# %%
df_all = pd.concat([df2010,
                    df2011,
                    df2012,
                    df2013,
                    df2014,
                    df2015,
                    df2016,
                    df2017,
                    df2018,
                    df2019,
                    df2020,
                    df2021])

df_all
# Out:
#       index     연도       시도  시군구 계약종별         1월         2월         3월  \
# 0         2  2010년    서울특별시  강남구  주택용      79292      74986      68798
# 1         3  2010년    서울특별시  강남구  일반용     349518     322874     278902
# 2         4  2010년    서울특별시  강남구  교육용       4531       4311       3724
# 3         5  2010년    서울특별시  강남구  산업용      17447      16078      16690
# 4         6  2010년    서울특별시  강남구  농사용        556        526        356
# ...     ...    ...      ...  ...  ...        ...        ...        ...
# 1830   1832   2021  세종특별자치시  세종시  합 계  334175873  304009818  296000438
# 1831   1833   2021     황해북도  개성시  주택용          0          0          0
# 1832   1834   2021     황해북도  개성시  일반용          0          0          0
# 1833   1835   2021     황해북도  개성시  산업용          0          0          0
# 1834   1836   2021     황해북도  개성시  합 계          0          0          0
#
#              4월         5월         6월         7월         8월         9월  \
# ...

# %%
df_all.head(5)
# Out:
#    index     연도     시도  시군구 계약종별      1월      2월      3월      4월      5월  \
# 0      2  2010년  서울특별시  강남구  주택용   79292   74986   68798   70793   67428
# 1      3  2010년  서울특별시  강남구  일반용  349518  322874  278902  279749  256752
# 2      4  2010년  서울특별시  강남구  교육용    4531    4311    3724    4110    2637
# 3      5  2010년  서울특별시  강남구  산업용   17447   16078   16690   16731   16741
# 4      6  2010년  서울특별시  강남구  농사용     556     526     356     340     250
#
#        6월      7월      8월      9월     10월     11월     12월
# 0   70911   80125   92559   80982   68500   70368   73862
# 1  293787  344233  372474  339004  257141  267997  311603
# 2    3261    4151    3096    4410    2476    3504    4847
# 3   16383   17159   15924   16410   16312   16434   17465
# 4     233     238     230     208     169     191     295

# %%
df_all = df_all.drop(df_all[df_all['시도'] == '황해북도'].index)
df_all.head(5)
# Out:
#    index     연도     시도  시군구 계약종별      1월      2월      3월      4월      5월  \
# 0      2  2010년  서울특별시  강남구  주택용   79292   74986   68798   70793   67428
# 1      3  2010년  서울특별시  강남구  일반용  349518  322874  278902  279749  256752
# 2      4  2010년  서울특별시  강남구  교육용    4531    4311    3724    4110    2637
# 3      5  2010년  서울특별시  강남구  산업용   17447   16078   16690   16731   16741
# 4      6  2010년  서울특별시  강남구  농사용     556     526     356     340     250
#
#        6월      7월      8월      9월     10월     11월     12월
# 0   70911   80125   92559   80982   68500   70368   73862
# 1  293787  344233  372474  339004  257141  267997  311603
# 2    3261    4151    3096    4410    2476    3504    4847
# 3   16383   17159   15924   16410   16312   16434   17465
# 4     233     238     230     208     169     191     295

# %%
df_all.reset_index()
df_all.head(10)
# Out:
#    index     연도     시도  시군구 계약종별      1월      2월      3월      4월      5월  \
# 0      2  2010년  서울특별시  강남구  주택용   79292   74986   68798   70793   67428
# 1      3  2010년  서울특별시  강남구  일반용  349518  322874  278902  279749  256752
# 2      4  2010년  서울특별시  강남구  교육용    4531    4311    3724    4110    2637
# 3      5  2010년  서울특별시  강남구  산업용   17447   16078   16690   16731   16741
# 4      6  2010년  서울특별시  강남구  농사용     556     526     356     340     250
# 5      7  2010년  서울특별시  강남구  가로등    3000    2786    2469    2405    2162
# 6      8  2010년  서울특별시  강남구   심야    3582    3333    2717    2781    3816
# 7      9  2010년  서울특별시  강남구   총계  457927  424894  373656  376910  349786
# 8     10  2010년  서울특별시  강동구  주택용   54938   53491   46423   49042   45876
# 9     11  2010년  서울특별시  강동구  일반용   69656   65933   53901   54927   49538
#
#        6월      7월      8월      9월     10월     11월     12월
# 0   70911   80125   92559   80982   68500   70368   73862
# ...

# %%
df_all.columns
# Out:
# Index(['index', '연도', '시도', '시군구', '계약종별', '1월', '2월', '3월', '4월', '5월', '6월',
#        '7월', '8월', '9월', '10월', '11월', '12월'],
#       dtype='object')

# %%
# df_all = df_all.drop(df_all[df_all['계약종별'] == '심야'].index)
df_all
# Out:
#       index     연도       시도  시군구 계약종별         1월         2월         3월  \
# 0         2  2010년    서울특별시  강남구  주택용      79292      74986      68798
# 1         3  2010년    서울특별시  강남구  일반용     349518     322874     278902
# 2         4  2010년    서울특별시  강남구  교육용       4531       4311       3724
# 3         5  2010년    서울특별시  강남구  산업용      17447      16078      16690
# 4         6  2010년    서울특별시  강남구  농사용        556        526        356
# ...     ...    ...      ...  ...  ...        ...        ...        ...
# 1825   1827   2021  세종특별자치시  세종시  교육용    9919429    7998599    7094752
# 1826   1828   2021  세종특별자치시  세종시  산업용  170948117  149379414  165118636
# 1827   1829   2021  세종특별자치시  세종시  농사용    8886933    8611497    7139862
# 1828   1830   2021  세종특별자치시  세종시  가로등    3281397    3111585    2839473
# 1829   1831   2021  세종특별자치시  세종시  심 야   13388874   12496456    9074443
#
#              4월         5월         6월         7월         8월         9월  \
# ...

# %%
df_test = df_all.loc[df_all['계약종별'].isin(['총계', '총 계'])]

# %%
df_test = df_test.reset_index()

# %%
df_test.columns
# Out:
# Index(['level_0', 'index', '연도', '시도', '시군구', '계약종별', '1월', '2월', '3월', '4월',
#        '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'],
#       dtype='object')

# %%
df_test.drop(['level_0'], axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[219], line 1
# ----> 1 df_test.drop(['level_0'], axis=0)
#
# File c:\Users\ssh\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\ssh\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df_test
# Out:
#      level_0  index     연도     시도  시군구 계약종별      1월      2월      3월      4월  \
# 0          7      9  2010년  서울특별시  강남구   총계  457927  424894  373656  376910
# 1         15     17  2010년  서울특별시  강동구   총계  144932  138528  118182  122005
# 2         23     25  2010년  서울특별시  강북구   총계   90056   87984   72971   76623
# 3         31     33  2010년  서울특별시  강서구   총계  186338  178368  153856  159663
# 4         39     41  2010년  서울특별시  관악구   총계  159420  154923  130358  138016
# ..       ...    ...    ...    ...  ...  ...     ...     ...     ...     ...
# 910     1794   1796  2013년   경상남도  통영시   총계  122958  110711  101443   96846
# 911     1802   1804  2013년   경상남도  하동군   총계   32786   32756   26148   25339
# 912     1810   1812  2013년   경상남도  함안군   총계  221006  202363  216666  216313
# 913     1818   1820  2013년   경상남도  함양군   총계   25568   24689   20370   20008
# 914     1826   1828  2013년   경상남도  합천군   총계   37159   36651   31184   29536
#
# ...

# %%
# data = pd.read_csv('전력 사용량 3차.csv')

# %%
data.head(100)
# Out:
#     Unnamed: 0  index     연도     시도   시군구 계약종별      1월      2월      3월  \
# 0            7      9  2010년  서울특별시   강남구   총계  457927  424894  373656
# 1           15     17  2010년  서울특별시   강동구   총계  144932  138528  118182
# 2           23     25  2010년  서울특별시   강북구   총계   90056   87984   72971
# 3           31     33  2010년  서울특별시   강서구   총계  186338  178368  153856
# 4           39     41  2010년  서울특별시   관악구   총계  159420  154923  130358
# ..         ...    ...    ...    ...   ...  ...     ...     ...     ...
# 95         765    767  2010년    경기도   오산시   총계  107689  100270   94706
# 96         773    775  2010년    경기도   용인시   총계  727884  722955  666194
# 97         781    783  2010년    경기도   의왕시   총계   62111   59305   51261
# 98         789    791  2010년    경기도  의정부시   총계  159178  150572  127795
# 99         797    799  2010년    경기도   이천시   총계  347928  329214  318275
#
#         4월      5월      6월      7월      8월      9월     10월     11월     12월
# ...

# %%
df = pd.read_csv('전력 사용량 3차.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', '연도', '시도', '시군구', '계약종별', '1월', '2월', '3월',
#        '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'],
#       dtype='object')

# %%
df = df[['연도', '시도', '시군구', '1월', '2월', '3월',
       '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월']]

# %%
df.loc[df['시도'].isin(['세종시'])]
# Out:
# Empty DataFrame
# Columns: [연도, 시도, 시군구, 1월, 2월, 3월, 4월, 5월, 6월, 7월, 8월, 9월, 10월, 11월, 12월]
# Index: []

# %%
sejong = pd.read_csv('전력 사용량 1차.csv')

# %%
sejong
# Out:
#        Unnamed: 0  index     연도       시도  시군구 계약종별         1월         2월  \
# 0               0      2  2010년    서울특별시  강남구  주택용      79292      74986
# 1               1      3  2010년    서울특별시  강남구  일반용     349518     322874
# 2               2      4  2010년    서울특별시  강남구  교육용       4531       4311
# 3               3      5  2010년    서울특별시  강남구  산업용      17447      16078
# 4               4      6  2010년    서울특별시  강남구  농사용        556        526
# ...           ...    ...    ...      ...  ...  ...        ...        ...
# 22091        1830   1832   2021  세종특별자치시  세종시  합 계  334175873  304009818
# 22092        1831   1833   2021     황해북도  개성시  주택용          0          0
# 22093        1832   1834   2021     황해북도  개성시  일반용          0          0
# 22094        1833   1835   2021     황해북도  개성시  산업용          0          0
# 22095        1834   1836   2021     황해북도  개성시  합 계          0          0
#
#               3월         4월         5월         6월         7월         8월  \
# ...

# %%
sejong = sejong.drop(sejong[sejong['시도'] == '황해북도'].index)

# %%
sejong
# Out:
#        Unnamed: 0  index     연도       시도  시군구 계약종별         1월         2월  \
# 0               0      2  2010년    서울특별시  강남구  주택용      79292      74986
# 1               1      3  2010년    서울특별시  강남구  일반용     349518     322874
# 2               2      4  2010년    서울특별시  강남구  교육용       4531       4311
# 3               3      5  2010년    서울특별시  강남구  산업용      17447      16078
# 4               4      6  2010년    서울특별시  강남구  농사용        556        526
# ...           ...    ...    ...      ...  ...  ...        ...        ...
# 22087        1826   1828   2021  세종특별자치시  세종시  산업용  170948117  149379414
# 22088        1827   1829   2021  세종특별자치시  세종시  농사용    8886933    8611497
# 22089        1828   1830   2021  세종특별자치시  세종시  가로등    3281397    3111585
# 22090        1829   1831   2021  세종특별자치시  세종시  심 야   13388874   12496456
# 22091        1830   1832   2021  세종특별자치시  세종시  합 계  334175873  304009818
#
#               3월         4월         5월         6월         7월         8월  \
# ...

# %%
sejong = sejong.reset_index()

# %%
# sejong.to_csv('전력 사용량 5차.csv')
sejong = pd.read_csv('전력 사용량 5차.csv')
sejong['계약종별'] = sejong['계약종별'].str.replace(' ', '')

# %%
sejong1 = sejong.loc[sejong['계약종별'].isin(['총계'])]
sejong2 = sejong.loc[sejong['계약종별'].isin(['합계'])]

# %%
data_sejong = pd.concat([sejong1, sejong2])
data_sejong['연도'] = data_sejong['연도'].str.replace('년', '')
data_sejong
# Out:
#        Unnamed: 0.1  level_0  Unnamed: 0  index    연도       시도   시군구 계약종별  \
# 7                 7        7           7      9  2010    서울특별시   강남구   총계
# 15               15       15          15     17  2010    서울특별시   강동구   총계
# 23               23       23          23     25  2010    서울특별시   강북구   총계
# 31               31       31          31     33  2010    서울특별시   강서구   총계
# 39               39       39          39     41  2010    서울특별시   관악구   총계
# ...             ...      ...         ...    ...   ...      ...   ...  ...
# 22005         22005    22059        1798   1800  2021     경상남도   거창군   합계
# 22013         22013    22067        1806   1808  2021     경상남도   합천군   합계
# 22021         22021    22075        1814   1816  2021  제주특별자치도   제주시   합계
# 22029         22029    22083        1822   1824  2021  제주특별자치도  서귀포시   합계
# 22037         22037    22091        1830   1832  2021  세종특별자치시   세종시   합계
#
#               1월         2월         3월         4월         5월         6월  \
# ...

# %%
# data_sejong.to_csv('전력 사용량 6차')

# %%
data = pd.read_csv("전력 사용량 6차.csv")
data['계약종별'] = data['계약종별'].str.replace('총계', '합계')
data = data.drop(columns=['시군구', '계약종별'])
data
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  level_0  Unnamed: 0  index    연도       시도  \
# 0                7             7        7           7      9  2010    서울특별시
# 1               15            15       15          15     17  2010    서울특별시
# 2               23            23       23          23     25  2010    서울특별시
# 3               31            31       31          31     33  2010    서울특별시
# 4               39            39       39          39     41  2010    서울특별시
# ...            ...           ...      ...         ...    ...   ...      ...
# 2756         22005         22005    22059        1798   1800  2021     경상남도
# 2757         22013         22013    22067        1806   1808  2021     경상남도
# 2758         22021         22021    22075        1814   1816  2021  제주특별자치도
# 2759         22029         22029    22083        1822   1824  2021  제주특별자치도
# 2760         22037         22037    22091        1830   1832  2021  세종특별자치시
#
# ...

# %%
data_test = data.groupby('시도').sum()

# %%
data_test = data_test.drop(columns=['Unnamed: 0.1', 'level_0', 'Unnamed: 0', 'index'])
data_test
# Out:
#                   1월           2월           3월           4월           5월  \
# 시도
# 강원도      12840719046  12302733938  11449190251  10964718135  10063998457
# 경기도      86603210405  82882324990  77411321682  74372031380  70508201326
# 경상남도     26304118559  25052025513  23791850144  22774421652  20946722049
# 경상북도     32495637242  30226075516  30410859891  29506176626  28592594237
# 광주광역시     6229481502   6045763397   5580768143   5479665732   5092666849
# 대구광역시    11272371965  10822969984   9919036695   9730039442   9132886823
# 대전광역시     6970851365   6696096885   6179022349   5946478483   5618555191
# 부산광역시    14890049079  14309800672  13443070513  13292893034  12528756256
# 서울특별시    34237649818  33126151695  28983392327  27877418010  26682199859
# 세종특별자치시   2159731259   2042213247   2006853270   1936599047   1837102526
# 울산광역시    22295209472  20400230356  21634052094  20942639619  21183391381
# 인천광역시    17609497469  16424363684  15996092736  15358076926  14732958794
# ...

# %%
data_test.to_csv('전력 사용량 월 시도월평균.csv')

# %%
data['연도', '시도', '시군구', '계약종별', '1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ssh\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\ssh\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\ssh\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('연도', '시도', '시군구', '계약종별', '1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월')
#
# ...

# %%
sejong.columns
# Out:
# Index(['level_0', 'Unnamed: 0', 'index', '연도', '시도', '시군구', '계약종별', '1월', '2월',
#        '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'],
#       dtype='object')

# %%
sejong['연도'] = sejong['연도'].str.replace('년', '')
sejong
# Out:
#       level_0  Unnamed: 0  index    연도       시도   시군구 계약종별      1월      2월  \
# 7           7           7      9  2010    서울특별시   강남구   총계  457927  424894
# 15         15          15     17  2010    서울특별시   강동구   총계  144932  138528
# 23         23          23     25  2010    서울특별시   강북구   총계   90056   87984
# 31         31          31     33  2010    서울특별시   강서구   총계  186338  178368
# 39         39          39     41  2010    서울특별시   관악구   총계  159420  154923
# ...       ...         ...    ...   ...      ...   ...  ...     ...     ...
# 7341     7359        1818   1820  2013     경상남도   함양군   총계   25568   24689
# 7349     7367        1826   1828  2013     경상남도   합천군   총계   37159   36651
# 7357     7375        1834   1836  2013  제주특별자치도  서귀포시   총계  142401  145239
# 7365     7383        1842   1844  2013  제주특별자치도   제주시   총계  231362  224884
# 7373     7391        1850   1852  2013  세종특별자치시   NaN   총계  215974  198312
#
# ...

# %%
sejong.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 923 entries, 7 to 7373
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   level_0     923 non-null    int64
#  1   Unnamed: 0  923 non-null    int64
#  2   index       923 non-null    int64
#  3   연도          923 non-null    object
#  4   시도          923 non-null    object
#  5   시군구         921 non-null    object
#  6   계약종별        923 non-null    object
#  7   1월          923 non-null    int64
#  8   2월          923 non-null    int64
#  9   3월          923 non-null    int64
#  10  4월          923 non-null    int64
#  11  5월          923 non-null    int64
#  12  6월          923 non-null    int64
#  13  7월          923 non-null    int64
#  14  8월          923 non-null    int64
#  15  9월          923 non-null    int64
#  16  10월         923 non-null    int64
#  17  11월         923 non-null    int64
#  18  12월         923 non-null    int64
# ...

# %%
sejong = sejong.drop(columns=['시군구', '계약종별'])

# %%
sejong
# Out:
#       level_0  Unnamed: 0  index    연도       시도      1월      2월      3월  \
# 7           7           7      9  2010    서울특별시  457927  424894  373656
# 15         15          15     17  2010    서울특별시  144932  138528  118182
# 23         23          23     25  2010    서울특별시   90056   87984   72971
# 31         31          31     33  2010    서울특별시  186338  178368  153856
# 39         39          39     41  2010    서울특별시  159420  154923  130358
# ...       ...         ...    ...   ...      ...     ...     ...     ...
# 7341     7359        1818   1820  2013     경상남도   25568   24689   20370
# 7349     7367        1826   1828  2013     경상남도   37159   36651   31184
# 7357     7375        1834   1836  2013  제주특별자치도  142401  145239  130391
# 7365     7383        1842   1844  2013  제주특별자치도  231362  224884  201198
# 7373     7391        1850   1852  2013  세종특별자치시  215974  198312  193991
#
#           4월      5월      6월      7월      8월      9월     10월     11월     12월
# ...

# %%
data_set = pd.read_csv('전력 사용량 6차.csv')

# %%
data_set.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'level_0', 'Unnamed: 0', 'index', '연도',
#        '시도', '시군구', '계약종별', '1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월',
#        '9월', '10월', '11월', '12월'],
#       dtype='object')

# %%
data_set = data_set[['연도',
       '시도', '시군구', '계약종별', '1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월',
       '9월', '10월', '11월', '12월']]

# %%
data_set.to_csv('전력 사용량 7차')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 data_set.to_csv('전력 사용량 7차')
#
# File c:\Users\ssh\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:987, in GroupBy.__getattr__(self, attr)
#     984 if attr in self.obj:
#     985     return self[attr]
# --> 987 raise AttributeError(
#     988     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'to_csv'

# %%
data_set = pd.read_csv('전력 사용량 7차.csv')

# %%
data = data_set[['연도', '시도', '1월', '2월', '3월', '4월', '5월',
       '6월', '7월', '8월', '9월', '10월', '11월', '12월']]

# %%
data = data.groupby(['연도', '시도']).sum()

# %%
data.to_csv('전력 사용량 8차.csv')

# %%
data
# Out:
#                       1월          2월          3월          4월          5월  \
# 연도   시도
# 2010 강원도         1480180     1382020     1308429     1317499     1185530
#      경기도         8725482     8341902     7574084     7727001     7156767
#      경상남도        2922775     2719682     2648326     2665253     2453568
#      경상북도        3743904     3471888     3484251     3454660     3321968
#      광주광역시        712924      682498      632293      642843      603935
# ...                  ...         ...         ...         ...         ...
# 2021 전라남도     2844658203  2738900197  2724004606  2670493390  2722102574
#      전라북도     1997136384  1830234267  1771152739  1725471485  1667691078
#      제주특별자치도   518257588   503323648   450804603   461822944   430958338
#      충청남도     4434196207  4039445323  4077386549  3876573166  3877528022
#      충청북도     2596409187  2373601172  2344911299  2274004059  2232679399
#
#                       6월          7월          8월          9월         10월  \
# ...

# %%
data = pd.read_csv('전력 사용량 8차.csv')

# %%
data.columns
# Out:
# Index(['연도', '시도', '1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월',
#        '11월', '12월'],
#       dtype='object')

# %%
data_T = data[['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월',
       '11월', '12월']].T

# %%
data_T
# Out:
#          0        1        2        3       4        5       6        7    \
# 1월   1480180  8725482  2922775  3743904  712924  1331473  826373  1848492
# 2월   1382020  8341902  2719682  3471888  682498  1269135  778458  1731722
# 3월   1308429  7574084  2648326  3484251  632293  1172936  716986  1635276
# 4월   1317499  7727001  2665253  3454660  642843  1199557  724076  1682021
# 5월   1185530  7156767  2453568  3321968  603935  1100160  664428  1571566
# 6월   1114450  7152029  2429359  3301601  605548  1119186  684218  1560178
# 7월   1055938  7589292  2550149  3344445  667137  1202680  748174  1675050
# 8월   1088438  7961584  2600386  3428974  697066  1284747  800784  1797007
# 9월   1058865  7659696  2594082  3394857  692544  1267503  770732  1806226
# 10월  1116695  6868326  2428098  3370268  605233  1080432  668362  1571374
# 11월  1297575  7866013  2623317  3498295  632721  1164842  705397  1616403
# 12월  1442404  8452695  2914222  3773932  685316  1287342  779416  1768368
#
# ...

# %%
df = pd.read_csv('전력 사용량 8차_test.csv')

# %%
pd.read_csv('전력 사용량 8차.csv')
# Out:
#        연도       시도          1월          2월          3월          4월  \
# 0    2010      강원도     1480180     1382020     1308429     1317499
# 1    2010      경기도     8725482     8341902     7574084     7727001
# 2    2010     경상남도     2922775     2719682     2648326     2665253
# 3    2010     경상북도     3743904     3471888     3484251     3454660
# 4    2010    광주광역시      712924      682498      632293      642843
# ..    ...      ...         ...         ...         ...         ...
# 197  2021     전라남도  2844658203  2738900197  2724004606  2670493390
# 198  2021     전라북도  1997136384  1830234267  1771152739  1725471485
# 199  2021  제주특별자치도   518257588   503323648   450804603   461822944
# 200  2021     충청남도  4434196207  4039445323  4077386549  3876573166
# 201  2021     충청북도  2596409187  2373601172  2344911299  2274004059
#
#              5월          6월          7월          8월          9월         10월  \
# 0       1185530     1114450     1055938     1088438     1058865     1116695
# ...

# %%
col = df['시도'] == "세종특별자치시"

# %%
col
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 199    False
# 200    False
# 201    False
# 202    False
# 203    False
# Name: 시도, Length: 204, dtype: bool

# %%
# df = pd.read_csv("전력 사용량 9차.csv")

# %%
df.columns
# Out:
# Index(['연도', '시도', '1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월',
#        '11월', '12월'],
#       dtype='object')

# %%
df_k = df[df['연도'] >=2014]

# %%
df = pd.read_csv("전력 사용량 9차.csv")

# %%
df_k = df[df['연도'] >=2014]
df_l = df_k[['연도', '시도']]
df_k
# Out:
#        연도       시도          1월          2월          3월          4월  \
# 68   2014      강원도  1559679072  1447941398  1394556099  1313297610
# 69   2014      경기도  9668915885  9131444136  8604749850  8295696225
# 70   2014     경상남도  3176344787  3029916113  2944133733  2820218739
# 71   2014     경상북도  4164536303  3841505811  4015412457  3880598303
# 72   2014    광주광역시   753935517   723755737   683278316   671402336
# ..    ...      ...         ...         ...         ...         ...
# 199  2021     전라남도  2844658203  2738900197  2724004606  2670493390
# 200  2021     전라북도  1997136384  1830234267  1771152739  1725471485
# 201  2021  제주특별자치도   518257588   503323648   450804603   461822944
# 202  2021     충청남도  4434196207  4039445323  4077386549  3876573166
# 203  2021     충청북도  2596409187  2373601172  2344911299  2274004059
#
#              5월          6월          7월          8월          9월         10월  \
# 68   1222477384  1164698520  1187271176  1214876814  1179708824  1226323928
# ...

# %%
df_k = round(df_k[['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월',
       '11월', '12월']] * 0.001)

# %%
df_k
# Out:
#             1월         2월         3월         4월         5월         6월  \
# 68   1559679.0  1447941.0  1394556.0  1313298.0  1222477.0  1164699.0
# 69   9668916.0  9131444.0  8604750.0  8295696.0  7798652.0  7996787.0
# 70   3176345.0  3029916.0  2944134.0  2820219.0  2590845.0  2590503.0
# 71   4164536.0  3841506.0  4015412.0  3880598.0  3727121.0  3731382.0
# 72    753936.0   723756.0   683278.0   671402.0   623437.0   651234.0
# ..         ...        ...        ...        ...        ...        ...
# 199  2844658.0  2738900.0  2724005.0  2670493.0  2722103.0  2648105.0
# 200  1997136.0  1830234.0  1771153.0  1725471.0  1667691.0  1697453.0
# 201   518258.0   503324.0   450805.0   461823.0   430958.0   437447.0
# 202  4434196.0  4039445.0  4077387.0  3876573.0  3877528.0  3770865.0
# 203  2596409.0  2373601.0  2344911.0  2274004.0  2232679.0  2283540.0
#
#             7월         8월         9월        10월        11월        12월
# ...

# %%
df_l
# Out:
#        연도       시도
# 68   2014      강원도
# 69   2014      경기도
# 70   2014     경상남도
# 71   2014     경상북도
# 72   2014    광주광역시
# ..    ...      ...
# 199  2021     전라남도
# 200  2021     전라북도
# 201  2021  제주특별자치도
# 202  2021     충청남도
# 203  2021     충청북도
#
# [136 rows x 2 columns]

# %%
df_k = df_k.astype(int)

# %%
df_k = pd.concat([df_l, df_k] ,axis=1)

# %%
df_k
# Out:
#        연도       시도       1월       2월       3월       4월       5월       6월  \
# 68   2014      강원도  1559679  1447941  1394556  1313298  1222477  1164699
# 69   2014      경기도  9668916  9131444  8604750  8295696  7798652  7996787
# 70   2014     경상남도  3176345  3029916  2944134  2820219  2590845  2590503
# 71   2014     경상북도  4164536  3841506  4015412  3880598  3727121  3731382
# 72   2014    광주광역시   753936   723756   683278   671402   623437   651234
# ..    ...      ...      ...      ...      ...      ...      ...      ...
# 199  2021     전라남도  2844658  2738900  2724005  2670493  2722103  2648105
# 200  2021     전라북도  1997136  1830234  1771153  1725471  1667691  1697453
# 201  2021  제주특별자치도   518258   503324   450805   461823   430958   437447
# 202  2021     충청남도  4434196  4039445  4077387  3876573  3877528  3770865
# 203  2021     충청북도  2596409  2373601  2344911  2274004  2232679  2283540
#
#           7월       8월       9월      10월      11월      12월
# ...

# %%
df_l = df[df['연도'] < 2014]
df_l
# Out:
#       연도       시도       1월       2월       3월       4월       5월       6월  \
# 0   2010      강원도  1480180  1382020  1308429  1317499  1185530  1114450
# 1   2010      경기도  8725482  8341902  7574084  7727001  7156767  7152029
# 2   2010     경상남도  2922775  2719682  2648326  2665253  2453568  2429359
# 3   2010     경상북도  3743904  3471888  3484251  3454660  3321968  3301601
# 4   2010    광주광역시   712924   682498   632293   642843   603935   605548
# ..   ...      ...      ...      ...      ...      ...      ...      ...
# 63  2013     전라남도  2616869  2462649  2561902  2526041  2563413  2481465
# 64  2013     전라북도  1955358  1840946  1884301  1859911  1773454  1719435
# 65  2013  제주특별자치도   373763   370123   331589   342968   315090   305151
# 66  2013     충청남도  4111575  3622246  3808302  3708208  3659904  3581215
# 67  2013     충청북도  2030193  1878491  1831061  1848760  1689801  1688244
#
#          7월       8월       9월      10월      11월      12월
# ...

# %%
df = pd.concat([df_l, df_k] ,axis=0)

# %%
df.to_csv('전력 사용량 10차.csv')
