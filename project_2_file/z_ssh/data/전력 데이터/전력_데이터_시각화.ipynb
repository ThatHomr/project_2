# %%
from matplotlib import font_manager, rc
import matplotlib
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.express as px
import seaborn as sns
import pandas as pd
import numpy as np
import platform
# 정규식
import re
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import matplotlib
#       3 import matplotlib.pyplot as plt
# ----> 4 import plotly.graph_objs as go
#       5 import plotly.express as px
#       6 import seaborn as sns
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# ## 폰트 지정

# %%
import platform
from matplotlib import font_manager, rc

if platform.system() == 'Windows':  # 현재 운영체제가 Windows인 경우
    # 폰트 파일 경로를 지정
    # 해당 폰트 파일의 이름 호출
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf"
                                            ).get_name()
    # 폰트 이름과 크기를 설정
    rc('font', family=font_name, size=8)
    plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('전력 사용량 10차.csv')

# %%
gangwon_do = df[df['시도'] == '강원도']
gangwon_do = gangwon_do.drop(columns=['시도', 'Unnamed: 0', '연도'])


gyeonggi = df[df['시도'] == '경기도']
gyeonggi = gyeonggi.drop(columns=['시도', 'Unnamed: 0', '연도'])


gyeongsangnam = df[df['시도'] == '경상남도']
gyeongsangnam = gyeongsangnam.drop(columns=['시도', 'Unnamed: 0', '연도'])


gyeongsangbuk = df[df['시도'] == '경상북도']
gyeongsangbuk = gyeongsangbuk.drop(columns=['시도', 'Unnamed: 0', '연도'])


gwangju = df[df['시도'] == '광주광역시']
gwangju = gwangju.drop(columns=['시도', 'Unnamed: 0', '연도'])


daegu = df[df['시도'] == '대구광역시']
daegu = daegu.drop(columns=['시도', 'Unnamed: 0', '연도'])


daejeon = df[df['시도'] == '대전광역시']
daejeon = daejeon.drop(columns=['시도', 'Unnamed: 0', '연도'])


busan = df[df['시도'] == '부산광역시']
busan = busan.drop(columns=['시도', 'Unnamed: 0', '연도'])


seoul = df[df['시도'] == '서울특별시']
seoul = seoul.drop(columns=['시도', 'Unnamed: 0', '연도'])


sejong = df[df['시도'] == '세종특별자치시']
sejong = sejong.drop(columns=['시도', 'Unnamed: 0', '연도'])


ulsan = df[df['시도'] == '울산광역시']
ulsan = ulsan.drop(columns=['시도', 'Unnamed: 0', '연도'])


incheon = df[df['시도'] == '인천광역시']
incheon = incheon.drop(columns=['시도', 'Unnamed: 0', '연도'])


jeonnam = df[df['시도'] == '전라남도']
jeonnam = jeonnam.drop(columns=['시도', 'Unnamed: 0', '연도'])


jeonbuk = df[df['시도'] == '전라북도']
jeonbuk = jeonbuk.drop(columns=['시도', 'Unnamed: 0', '연도'])


jeju = df[df['시도'] == '제주특별자치도']
jeju = jeju.drop(columns=['시도', 'Unnamed: 0', '연도'])


chungnam = df[df['시도'] == '충청남도']
chungnam = chungnam.drop(columns=['시도', 'Unnamed: 0', '연도'])


chungbuk = df[df['시도'] == '충청북도']
chungbuk = chungbuk.drop(columns=['시도', 'Unnamed: 0', '연도'])

# %%
df_seoul = df[df['시도'] == '서울특별시']
df_seoul = df_seoul.drop(columns=['시도', 'Unnamed: 0', '연도'])
df_seoul
# Out:
#           1월       2월       3월       4월       5월       6월       7월       8월  \
# 8    4398183  4168168  3624186  3719082  3426951  3729030  4219590  4646112
# 25   4562632  4264449  3736362  3682652  3425703  3713716  4049595  4433093
# 42   4349335  4298788  3837539  3695515  3483656  3736558  4075847  4687134
# 59   4486310  4189413  3652776  3638393  3439856  3706936  4099931  4534870
# 76   4155574  3974971  3547923  3466188  3305028  3649218  4072242  4260833
# 93   4281117  4023566  3592926  3512071  3324249  3637371  3982172  4471860
# 110  4151770  4174917  3729909  3457927  3340823  3715673  4101888  4852558
# 127  4139967  4166700  3649111  3470755  3290791  3621612  4273771  4733095
# 144  4477102  4469940  3657824  3503967  3366946  3686242  4260544  5394746
# 161  4416889  4127699  3582654  3591552  3419987  3676047  4146986  4897882
# 178  4197026  4037392  3657444  3410967  3295839  3730294  4074026  4438534
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '연도', '시도', '1월', '2월', '3월', '4월', '5월', '6월', '7월',
#        '8월', '9월', '10월', '11월', '12월'],
#       dtype='object')

# %%
df_2 = df[['연도', '시도', '1월', '2월', '3월', '4월', '5월', '6월', '7월',
       '8월', '9월', '10월', '11월', '12월']]

# %%
df_1 = df.drop(columns=['Unnamed: 0', '시도', '연도'])
df_1
# Out:
#           1월       2월       3월       4월       5월       6월       7월       8월  \
# 0    1480180  1382020  1308429  1317499  1185530  1114450  1055938  1088438
# 1    8725482  8341902  7574084  7727001  7156767  7152029  7589292  7961584
# 2    2922775  2719682  2648326  2665253  2453568  2429359  2550149  2600386
# 3    3743904  3471888  3484251  3454660  3321968  3301601  3344445  3428974
# 4     712924   682498   632293   642843   603935   605548   667137   697066
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 199  2844658  2738900  2724005  2670493  2722103  2648105  2856350  3073050
# 200  1997136  1830234  1771153  1725471  1667691  1697453  1803462  1923328
# 201   518258   503324   450805   461823   430958   437447   486838   544310
# 202  4434196  4039445  4077387  3876573  3877528  3770865  4137216  4257399
# 203  2596409  2373601  2344911  2274004  2232679  2283540  2404437  2507863
#
#           9월      10월      11월      12월
# ...

# %%
plt.figure(figsize = (16,3))
plt.plot(df_seoul, marker = 'o', markersize=1)
plt.grid(axis='y', linestyle='-', alpha=0.4)
plt.legend(df_1.columns,
           loc='center left', bbox_to_anchor=(1, 0.5)) # 그래프 범례를 그래프 밖에 위치
plt.title('2010~2021 월별 사용량 (mwh)')
plt.xlabel('월')
plt.ylabel('사용량(kWh)')
# plt.autoscale(axis='x', tight=True)
plt.show()

# %%
plt.figure(figsize = (16,3))
plt.plot(df_1, marker = 'o', markersize=1)
plt.grid(axis='y', linestyle='-', alpha=0.4)
plt.legend(df_1.columns,
           loc='center left', bbox_to_anchor=(1, 0.5)) # 그래프 범례를 그래프 밖에 위치
plt.title('2010~2021 서울 특별시 월별 사용량 (mwh)')
plt.xlabel('월')
plt.ylabel('사용량(kWh)')
# plt.autoscale(axis='x', tight=True)
plt.show()

# %%
# 그래프 크기 설정
plt.figure(figsize=(19, 6))

# 데이터프레임을 이용하여 그래프 그리기
plt.plot(df_1, marker='o', markersize=1)

# y축에 그리드 추가
plt.grid(axis='y', linestyle='-', alpha=0.5)

# 그래프 범례를 그래프 밖에 위치
plt.legend(df_1.columns, loc='center left', bbox_to_anchor=(1, 0.5))

# 그래프 제목 설정
plt.title('2010~2021 월별 사용량 (mwh)')

# x축 레이블 설정
plt.xlabel('월')

# y축 레이블 설정
plt.ylabel('사용량(mWh)')

# x, y축 범위 자동으로 설정
plt.autoscale(axis='x', tight=True)
plt.autoscale(axis='y', tight=True)

# 그래프 출력
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Pivot the dataframe to have months as rows and years as columns
df_pivot = df_seoul.pivot(index='1월', columns='시도', values='2월')

# Create a line chart with the pivoted dataframe
df_pivot.plot.line()

# Add labels and title to the chart
plt.xlabel('Month')
plt.ylabel('Usage')
plt.title('Power Usage by Year and Month')

# Display the chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '시도'
#
# The above exception was the direct cause of the following exception:
#
# ...
