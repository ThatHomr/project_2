# %%
import pandas as pd

# %%
i = pd.read_excel("1일차시군구별_의료인력현황Ⅰ_의사_약사_등__20230426153511_분석(전년말분기_대비_증감,증감률).xlsx")
i
# Out:
# c:\Users\admin\AppData\Local\anaconda3\envs\gj_202304\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     시군구별(1) 2018.1/4   2018.1/4.1 2018.1/4.2 2018.1/4.3   2018.1/4.4
# 0   시군구별(1)       전체           전체         전체         의사           의사  \
# 1   시군구별(1)       소계           소계         소계         소계           소계
# 2   시군구별(1)     원데이터  전년말분기 대비 증감        증감률       원데이터  전년말분기 대비 증감
# 3        전체   232211          NaN        NaN     101060          NaN
# 4        서울    58433          NaN        NaN      28826          NaN
# 5        부산    17667          NaN        NaN       7779          NaN
# 6        대구    12658          NaN        NaN       5588          NaN
# 7        인천    11578          NaN        NaN       4769          NaN
# 8        광주     8342          NaN        NaN       3458          NaN
# ...

# %%
###2021년 4분기 의료인력 , 의사,한의사
data1 = i[["시군구별(1)","2021.4/4"]]
# Out:
#     시군구별(1) 2021.4/4
# 0   시군구별(1)       전체
# 1   시군구별(1)       소계
# 2   시군구별(1)     원데이터
# 3        전체   258308
# 4        서울    65199
# 5        부산    19376
# 6        대구    14222
# 7        인천    13105
# 8        광주     8962
# 9        대전     8759
# 10       울산     4490
# 11       세종     1185
# 12       경기    56527
# 13       강원     6455
# 14       충북     6687
# 15       충남     8404
# 16       전북     9400
# 17       전남     8491
# 18       경북     9662
# 19       경남    14404
# 20       제주     2980

# %%
data2 = data1.drop([0,1,2,3])
data2
# Out:
#    시군구별(1) 2021.4/4
# 4       서울    65199
# 5       부산    19376
# 6       대구    14222
# 7       인천    13105
# 8       광주     8962
# 9       대전     8759
# 10      울산     4490
# 11      세종     1185
# 12      경기    56527
# 13      강원     6455
# 14      충북     6687
# 15      충남     8404
# 16      전북     9400
# 17      전남     8491
# 18      경북     9662
# 19      경남    14404
# 20      제주     2980

# %%
##2021/4분기만 가져오기 
data3 =data2['2021.4/4']
data3
# Out:
# 4     65199
# 5     19376
# 6     14222
# 7     13105
# 8      8962
# 9      8759
# 10     4490
# 11     1185
# 12    56527
# 13     6455
# 14     6687
# 15     8404
# 16     9400
# 17     8491
# 18     9662
# 19    14404
# 20     2980
# Name: 2021.4/4, dtype: object

# %%
##분기값 3으로나누기 
val = data3['2021.4/4']/3
val
# Out:
# 시군구별(1)
# 서울         21733.0
# 부산     6458.666667
# 대구     4740.666667
# 인천     4368.333333
# 광주     2987.333333
# 대전     2919.666667
# 울산     1496.666667
# 세종           395.0
# 경기    18842.333333
# 강원     2151.666667
# 충북          2229.0
# 충남     2801.333333
# 전북     3133.333333
# 전남     2830.333333
# 경북     3220.666667
# 경남     4801.333333
# 제주      993.333333
# Name: 2021.4/4, dtype: object

# %%
data2['2021.4/4'] = data2['2021.4/4']/3
