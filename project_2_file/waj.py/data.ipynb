# %%
import pandas as pd

# %%
i = pd.read_excel("1일차시군구별_의료인력현황Ⅰ_의사_약사_등__20230426153511_분석(전년말분기_대비_증감,증감률).xlsx")
# Out:
# c:\Users\admin\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Columns: 1270 entries, 시군구별(1) to 2022.4/4.65
# dtypes: object(1270)
# memory usage: 208.5+ KB

# %%
i
# Out:
#     시군구별(1) 2018.1/4   2018.1/4.1 2018.1/4.2 2018.1/4.3   2018.1/4.4  \
# 0   시군구별(1)       전체           전체         전체         의사           의사
# 1   시군구별(1)       소계           소계         소계         소계           소계
# 2   시군구별(1)     원데이터  전년말분기 대비 증감        증감률       원데이터  전년말분기 대비 증감
# 3        전체   232211          NaN        NaN     101060          NaN
# 4        서울    58433          NaN        NaN      28826          NaN
# 5        부산    17667          NaN        NaN       7779          NaN
# 6        대구    12658          NaN        NaN       5588          NaN
# 7        인천    11578          NaN        NaN       4769          NaN
# 8        광주     8342          NaN        NaN       3458          NaN
# 9        대전     8247          NaN        NaN       3598          NaN
# 10       울산     4223          NaN        NaN       1722          NaN
# 11       세종      745          NaN        NaN        258          NaN
# 12       경기    48465          NaN        NaN      19965          NaN
# ...

# %%
i.iloc[2] == "원데이터"
i.T
# Out:
#                   0        1            2       3      4      5      6   \
# 시군구별(1)      시군구별(1)  시군구별(1)      시군구별(1)      전체     서울     부산     대구
# 2018.1/4          전체       소계         원데이터  232211  58433  17667  12658
# 2018.1/4.1        전체       소계  전년말분기 대비 증감     NaN    NaN    NaN    NaN
# 2018.1/4.2        전체       소계          증감률     NaN    NaN    NaN    NaN
# 2018.1/4.3        의사       소계         원데이터  101060  28826   7779   5588
# ...              ...      ...          ...     ...    ...    ...    ...
# 2022.4/4.61    작업치료사       소계  전년말분기 대비 증감     NaN    NaN    NaN    NaN
# 2022.4/4.62    작업치료사       소계          증감률     NaN    NaN    NaN    NaN
# 2022.4/4.63    사회복지사       소계         원데이터    4319    586    381    236
# 2022.4/4.64    사회복지사       소계  전년말분기 대비 증감     NaN    NaN    NaN    NaN
# 2022.4/4.65    사회복지사       소계          증감률     NaN    NaN    NaN    NaN
#
#                 7     8     9   ...   11     12    13    14    15    16    17  \
# ...

# %%
column = i.loc[:1]
column
# Out:
#    시군구별(1) 2018.1/4 2018.1/4.1 2018.1/4.2 2018.1/4.3 2018.1/4.4 2018.1/4.5  \
# 0  시군구별(1)       전체         전체         전체         의사         의사         의사
# 1  시군구별(1)       소계         소계         소계         소계         소계         소계
#
#   2018.1/4.6 2018.1/4.7 2018.1/4.8  ... 2022.4/4.56 2022.4/4.57 2022.4/4.58  \
# 0         의사         의사         의사  ...         한약사       물리치료사       물리치료사
# 1        일반의        일반의        일반의  ...          소계          소계          소계
#
#   2022.4/4.59 2022.4/4.60 2022.4/4.61 2022.4/4.62 2022.4/4.63 2022.4/4.64  \
# 0       물리치료사       작업치료사       작업치료사       작업치료사       사회복지사       사회복지사
# 1          소계          소계          소계          소계          소계          소계
#
#   2022.4/4.65
# 0       사회복지사
# 1          소계
#
# [2 rows x 1270 columns]
