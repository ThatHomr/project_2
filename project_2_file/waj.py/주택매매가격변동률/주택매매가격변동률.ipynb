# %%
import pandas as pd

# %%
data = pd.read_csv("201001_202112_월별_시도별_주택매매가격변동률.csv", encoding="cp949")

# %%
data
# Out:
#    행정구역별(1) 2010.01 2010.02 2010.03 2010.04 2010.05 2010.06 2010.07 2010.08
# 0        전국    0.13    0.26    0.22    0.17    0.02       0   -0.16    -0.1  \
# 1     서울특별시    0.13    0.23    0.07   -0.02   -0.25   -0.24   -0.34   -0.38
# 2     부산광역시    0.36    0.76    0.95    1.13    0.91    0.72    0.53    0.49
# 3     대구광역시    0.09    0.11    0.03     0.2    0.09   -0.02   -0.02    0.07
# 4     인천광역시    0.05    0.02    0.03   -0.16   -0.24   -0.21   -0.42   -0.28
# 5     광주광역시    0.07    0.09   -0.01    0.08    0.21   -0.02   -0.07    0.06
# 6     대전광역시    0.63    0.93     0.5    0.62    0.68    0.28    0.18    0.47
# 7     울산광역시    0.24    0.41    0.26    0.36    0.42    0.13    0.13    0.03
# 8   세종특별자치시       -       -       -       -       -       -       -       -
# 9       경기도   -0.06    0.04    0.01   -0.11   -0.48   -0.46   -0.71   -0.49
# 10      강원도    0.13    0.22    0.31    0.19    0.06     0.1    0.29    0.19
# ...
