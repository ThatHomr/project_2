# %%
### 데이터프레임을 사용할 수 있는 라이브러리 불러들이기
import pandas as pd
### 시각화 라이브러리 불러들이기
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
file_path = "./전력량_물가지수.csv"
pop_data = pd.read_csv(file_path)
pop_data.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# pop_data['사용량'] = pop_data['전력소비량']
# pop_data.drop(columns=['전력소비량'], inplace=True)
pop_data
# Out:
#        연도   월     물가지수      사용량
# 0    2010   1   85.351  2335102
# 1    2010   2   85.523  2188707
# 2    2010   3   85.696  2091419
# 3    2010   4   86.041  2115785
# 4    2010   5   86.128  1988778
# ..    ...  ..      ...      ...
# 139  2021   8  102.750  2878232
# 140  2021   9  103.170  2636404
# 141  2021  10  103.350  2461071
# 142  2021  11  103.870  2519389
# 143  2021  12  104.040  2779448
#
# [144 rows x 4 columns]

# %%
pop_data

# %%
pop_data
# Out:
#        연도   월     물가지수      사용량
# 0    2010   1   85.351  2335102  \
# 1    2010   2   85.523  2188707
# 2    2010   3   85.696  2091419
# 3    2010   4   86.041  2115785
# 4    2010   5   86.128  1988778
# ..    ...  ..      ...      ...
# 139  2021   8  102.750  2878232
# 140  2021   9  103.170  2636404
# 141  2021  10  103.350  2461071
# 142  2021  11  103.870  2519389
# 143  2021  12  104.040  2779448
#
#                                                     연월
# 0    0      2010\n1      2010\n2      2010\n3      ...
# 1    0      2010\n1      2010\n2      2010\n3      ...
# 2    0      2010\n1      2010\n2      2010\n3      ...
# 3    0      2010\n1      2010\n2      2010\n3      ...
# 4    0      2010\n1      2010\n2      2010\n3      ...
# ..                                                 ...
# 139  0      2010\n1      2010\n2      2010\n3      ...
# 140  0      2010\n1      2010\n2      2010\n3      ...
# 141  0      2010\n1      2010\n2      2010\n3      ...
# 142  0      2010\n1      2010\n2      2010\n3      ...
# 143  0      2010\n1      2010\n2      2010\n3      ...
#
# [144 rows x 5 columns]

# %%
# pop_data.to_csv('전력량_물가지수.csv')

# %%
        
df_ver = pop_data
df_data = df_ver[['연도', '월', '사용량', '물가지수']]
df_data_test = df_data.to_dict(orient='records')
df_data
# Out:
#        연도   월      사용량     물가지수
# 0    2010   1  2335102   85.351
# 1    2010   2  2188707   85.523
# 2    2010   3  2091419   85.696
# 3    2010   4  2115785   86.041
# 4    2010   5  1988778   86.128
# ..    ...  ..      ...      ...
# 139  2021   8  2878232  102.750
# 140  2021   9  2636404  103.170
# 141  2021  10  2461071  103.350
# 142  2021  11  2519389  103.870
# 143  2021  12  2779448  104.040
#
# [144 rows x 4 columns]

# %%
# 첫번째 x축을 기준으로 그래프 생성
trace1 = go.Scatter(
    x = df_data[["연도","월"]],
    y = df_data["사용량"],
    name='전력 사용량'
)

# 두번째 x축을 기준으로 그래프 생성
trace2 = go.Scatter(
    x = df_data[],
    y = df_data["물가지수"],
    name='물가지수',
    yaxis='y2'
)

# 하나의 x축과 두 개의 y축으로 레이아웃 생성
layout = go.Layout(
    title='전력 사용량 VS 물가지수',
    yaxis=dict(
        title='전력 사용량'
    ),
    yaxis2=dict(
        title='물가지수',
        overlaying='y',
        side='right'
    )
)

# 레이아웃 조합 후 그래프 작성
fig = go.Figure(data=[trace1, trace2], layout=layout)
fig
